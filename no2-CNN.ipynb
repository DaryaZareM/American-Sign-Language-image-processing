# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, Flatten, MaxPooling2D, Dropout, BatchNormalization
import csv
import numpy
import keras
from matplotlib import pyplot as plt
import tensorflow as tf
from sklearn import preprocessing

# %% [markdown]
# ## read csv
# #### read train and test
# #### seprate lables

# %%
reader = csv.reader(open("sign_mnist_train.csv", "r"), delimiter=",")
xtrain = list(reader)
xtrain=xtrain[1:]
train_data = numpy.array(xtrain).astype("int")

# %%
reader = csv.reader(open("sign_mnist_test.csv", "r"), delimiter=",")
xtest = list(reader)
xtest=xtest[1:]
test_data = numpy.array(xtest).astype("int")

# %%
train_lable = train_data[:,0]
train_pixel = train_data[:,1:]

# %%
test_lable = test_data[:,0]
test_pixel = test_data[:,1:]

# %%
temp=train_pixel
temp=temp.reshape(temp.shape[0],28,28,1)
temp.shape
# Out:
# (27455, 28, 28, 1)

# %%
testam=test_pixel
testam=testam.reshape(testam.shape[0],28,28,1)
testam.shape
# Out:
# (7172, 28, 28, 1)

# %% [markdown]
# #  normalize train_pixel and test_pixel

# %%
import pandas as pd
x = temp #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
norm_train_pixel = pd.DataFrame(x_scaled)

# %%
x = test_pixel #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
norm_test_pixel = pd.DataFrame(x_scaled)

# %% [markdown]
# ### tensor <-- numpy

# %%
data_tf = tf.convert_to_tensor(temp, numpy.float32)
lable_tf = tf.convert_to_tensor(train_lable, numpy.float32)

# %%
lable_tf =tf.keras.utils.to_categorical(lable_tf,26)
tl = tf.keras.utils.to_categorical(test_lable,26)

# %%
lable_tf.shape
# Out:
# (27455, 26)

# %% [markdown]
# #  creating model

# %%
#create model
model1 = Sequential()
#add model layers
model1.add(Conv2D(7, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model1.add(Conv2D(9, kernel_size=3, activation='relu'))

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(rate=0.25))      
model1.add(Flatten())
model1.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # الف
# # 3 لایه پیچشی

# %%
#create model
model2 = Sequential()
#add model layers
model2.add(Conv2D(7, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(9, kernel_size=3, activation='relu'))
model2.add(Conv2D(9, kernel_size=3, activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.25))      
model2.add(Flatten())
model2.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # الف
# ## 4 لایه پیچشی

# %%
#create model
model3 = Sequential()
#add model layers
model3.add(Conv2D(7, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model3.add(Conv2D(9, kernel_size=3, activation='relu'))
model3.add(Conv2D(9, kernel_size=3, activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(rate=0.25))      
model3.add(Flatten())
model3.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ب
# ## 5 * 5

# %%
#create model
model4 = Sequential()
#add model layers
model4.add(Conv2D(7, kernel_size=5, activation='relu', input_shape=(28,28,1)))
model4.add(Conv2D(9, kernel_size=3, activation='relu'))

model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(rate=0.25))      
model4.add(Flatten())
model4.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ب
# ## 7 * 7

# %%
#create model
model5 = Sequential()
#add model layers
model5.add(Conv2D(7, kernel_size=7, activation='relu', input_shape=(28,28,1)))
model5.add(Conv2D(9, kernel_size=3, activation='relu'))

model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(rate=0.25))      
model5.add(Flatten())
model5.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'],  loc='upper left')
plt.show()

# %% [markdown]
# #  پ

# %%
#create model
model6 = Sequential()
#add model layers
model6.add(Conv2D(7, kernel_size=5, activation='relu', input_shape=(28,28,1)))

model6.add(MaxPooling2D(pool_size=(2, 2)))
model6.add(Dropout(rate=0.25))      
model6.add(Flatten())
model6.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ت
# ## learning rate=0.4

# %%
model=model1
opt = keras.optimizers.Adam(learning_rate=0.4)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'] )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ت
# ## learning rate=0.3

# %%
model=model1
opt = keras.optimizers.Adam(learning_rate=0.3)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'] )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ت
# ## learning rate=0.1

# %%
model=model1
opt = keras.optimizers.Adam(learning_rate=0.1)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'] )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #  ث
# ## تابع LeakyReLU

# %%
#create model
model7 = Sequential()
#add model layers
model7.add(Conv2D(7, kernel_size=3, activation = tf.keras.layers.LeakyReLU(alpha=0.1), input_shape=(28,28,1)))
model7.add(Conv2D(9, kernel_size=3, activation = tf.keras.layers.LeakyReLU(alpha=0.1)))

model7.add(MaxPooling2D(pool_size=(2, 2)))
model7.add(Dropout(rate=0.25))      
model7.add(Flatten())
model7.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ث
#
# ##  tanh تابع

# %%
#create model
model8 = Sequential()
#add model layers
model8.add(Conv2D(7, kernel_size=3, activation='tanh', input_shape=(28,28,1)))
model8.add(Conv2D(9, kernel_size=3, activation='tanh'))

model8.add(MaxPooling2D(pool_size=(2, 2)))
model8.add(Dropout(rate=0.25))      
model8.add(Flatten())
model8.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ج
# ## SGD

# %%
model=model1
opt = keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'] )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ج
# ## Adagrad

# %%
model=model1
opt = keras.optimizers.Adagrad(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'] )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # چ
# ### BatchNormalization

# %%
#create model
model9 = Sequential()
#add model layers

model9.add(BatchNormalization(input_shape=(28,28,1)))
model9.add(Conv2D(9, kernel_size=3, activation='relu'))

model9.add(MaxPooling2D(pool_size=(2, 2)))
model9.add(Dropout(rate=0.25))      
model9.add(Flatten())
model9.add(Dense(26, activation='softmax'))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ح
# ## BATCH_SIZE = 4

# %%
history = model.fit(data_tf,lable_tf ,validation_split=0.1, batch_size=4, epochs=25,callbacks=[callbacks])
# Out:
# Epoch 1/25
# 6178/6178 [==============================] - 25s 4ms/step - loss: 3.2457 - accuracy: 0.0453 - val_loss: 3.1821 - val_accuracy: 0.0430
# Epoch 2/25
# 6178/6178 [==============================] - 25s 4ms/step - loss: 3.1961 - accuracy: 0.0459 - val_loss: 3.1759 - val_accuracy: 0.0459
# Epoch 3/25
# 6178/6178 [==============================] - 25s 4ms/step - loss: 3.1836 - accuracy: 0.0475 - val_loss: 3.1691 - val_accuracy: 0.0524
# Epoch 4/25
# 6178/6178 [==============================] - 25s 4ms/step - loss: 3.1741 - accuracy: 0.0476 - val_loss: 3.1736 - val_accuracy: 0.0422
# Epoch 5/25
# 6178/6178 [==============================] - 25s 4ms/step - loss: 3.1751 - accuracy: 0.0473 - val_loss: 3.1693 - val_accuracy: 0.0492
# Epoch 6/25
# 6178/6178 [==============================] - 25s 4ms/step - loss: 3.1739 - accuracy: 0.0457 - val_loss: 3.1683 - val_accuracy: 0.0524
# Epoch 7/25
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # ح
# ## BATCH_SIZE = 128

# %%
history = model.fit(data_tf,lable_tf ,validation_split=0.1, batch_size=128, epochs=25,callbacks=[callbacks])
# Out:
# Epoch 1/25
# 194/194 [==============================] - 7s 35ms/step - loss: 3.1774 - accuracy: 0.0435 - val_loss: 3.1777 - val_accuracy: 0.0477
# Epoch 2/25
# 194/194 [==============================] - 5s 27ms/step - loss: 3.1767 - accuracy: 0.0452 - val_loss: 3.1790 - val_accuracy: 0.0499
# Epoch 3/25
# 194/194 [==============================] - 5s 28ms/step - loss: 3.1768 - accuracy: 0.0437 - val_loss: 3.1777 - val_accuracy: 0.0477
# Epoch 4/25
# 194/194 [==============================] - 6s 28ms/step - loss: 3.1768 - accuracy: 0.0463 - val_loss: 3.1773 - val_accuracy: 0.0477
# Epoch 5/25
# 194/194 [==============================] - 6s 29ms/step - loss: 3.1766 - accuracy: 0.0453 - val_loss: 3.1779 - val_accuracy: 0.0499
# Epoch 6/25
# 194/194 [==============================] - 6s 30ms/step - loss: 3.1769 - accuracy: 0.0429 - val_loss: 3.1783 - val_accuracy: 0.0477
# Epoch 7/25
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model=model9

# %%
VAL_LOSS_THRESHOLD = 0.001

# %%
# Implement callback function to stop training
class myCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('val_loss') < VAL_LOSS_THRESHOLD):   
            print("\nReached %2.2f%% val_loss, so stopping training!!" %(VAL_LOSS_THRESHOLD*100))   
            self.model.stop_training = True

# %%
callbacks = myCallback()

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'] )

# %%
history = model.fit(data_tf,lable_tf ,validation_split=0.1, batch_size=32, epochs=25,callbacks=[callbacks])
# Out:
# Epoch 1/25
# 773/773 [==============================] - 5s 7ms/step - loss: 0.2746 - accuracy: 0.9207 - val_loss: 0.0190 - val_accuracy: 0.9949
# Epoch 2/25
# 773/773 [==============================] - 5s 7ms/step - loss: 0.0495 - accuracy: 0.9855 - val_loss: 0.0221 - val_accuracy: 0.9934
# Epoch 3/25
# 773/773 [==============================] - 5s 7ms/step - loss: 0.0346 - accuracy: 0.9898 - val_loss: 0.0105 - val_accuracy: 0.9956
# Epoch 4/25
# 773/773 [==============================] - 5s 7ms/step - loss: 0.0287 - accuracy: 0.9918 - val_loss: 0.0026 - val_accuracy: 0.9993
# Epoch 5/25
# 767/773 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9921
# Reached 0.10% val_loss, so stopping training!!
# 773/773 [==============================] - 5s 7ms/step - loss: 0.0266 - accuracy: 0.9921 - val_loss: 9.0572e-04 - val_accuracy: 0.9996

# %%
predictions = model.predict(
    x=testam, 
    batch_size=32, 
    verbose=0
)

# %%
history.history
# Out:
# {'loss': [3.308616876602173,
#   2.696857452392578,
#   1.4543081521987915,
#   1.0448435544967651,
#   1.044188380241394,
#   0.9562608003616333,
#   0.9439762234687805,
#   0.8871424198150635,
#   0.8790749311447144,
#   0.9159450531005859,
#   1.0070703029632568,
#   0.9314185380935669,
#   0.9226880669593811,
#   0.8953822255134583,
#   0.8538296818733215,
#   0.9008966088294983,
#   0.9953455328941345,
#   1.0237845182418823,
#   0.9935177564620972,
#   0.9215114116668701,
#   0.9038410782814026,
#   0.9664297103881836,
#   0.9156428575515747,
#   0.9924044609069824,
#   0.9725326299667358],
#  'accuracy': [0.05184345692396164,
#   0.2068072408437729,
#   0.5488283634185791,
#   0.6678943037986755,
#   0.6708081960678101,
#   0.6999474167823792,
#   0.7023351788520813,
#   0.7155287265777588,
#   0.7188878655433655,
#   0.7070702910423279,
#   0.6868752241134644,
#   0.7059775590896606,
#   0.7046015858650208,
#   0.713586151599884,
#   0.7244324088096619,
# ...
